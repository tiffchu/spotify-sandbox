# %% [markdown]
# <a href="https://colab.research.google.com/github/tiffchu/spotify-sandbox/blob/main/sandbox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy
# !pip install python-dotenv
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Set up authentication
client_credentials_manager = SpotifyClientCredentials(client_id='0589c99cf427431fb1310f48ca148b77', client_secret='ba3220b53ef241ee9e4869685e3070a9')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Search for Kendrick Lamar
results = sp.search(q='Kendrick Lamar', type='artist')
kendrick_id = results['artists']['items'][0]['id']

# %%
# Get Kendrick Lamar's top tracks
tracks = sp.artist_top_tracks(kendrick_id)

# %%
# Extract track IDs
track_ids = [track['id'] for track in tracks['tracks']]

# %%
# Get audio features for each track
song_features = []
for track_id in track_ids:
    features = sp.audio_features([track_id])
    song_features.extend(features)

# %%
# Create DataFrame
df = pd.DataFrame(song_features)

# %%
# Select only relevant columns
df = df[['name', 'id', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c7c6b638df96> in <cell line: 2>()
#       1 # Select only relevant columns
# ----> 2 df = df[['name', 'id', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# ...

# %%
# Print DataFrame
df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.814   0.676   11    -4.670     0       0.2310      0.007090
# 1         0.695   0.633    8    -4.946     1       0.0599      0.061200
# 2         0.716   0.531    7    -7.355     1       0.1220      0.070300
# 3         0.908   0.621    1    -6.638     0       0.1020      0.000282
# 4         0.800   0.585   10    -7.343     1       0.0924      0.264000
# 5         0.665   0.535    4    -7.056     0       0.0572      0.078600
# 6         0.711   0.611    1    -5.453     1       0.3300      0.005880
# 7         0.693   0.445    8    -5.892     1       0.2570      0.006250
# 8         0.796   0.766    7    -5.974     1       0.2380      0.074200
# 9         0.638   0.523    1    -6.664     1       0.3570      0.004540
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000013    0.1190    0.312  162.012  audio_features
# ...

# %%
# Get audio features for each track
song_features = []
song_titles = []  # Initialize a list to store song titles
for track_id in track_ids:
    features = sp.audio_features([track_id])
    song_features.extend(features)
    # Extract song titles
    track_info = sp.track(track_id)
    song_titles.append(track_info['name'])

# Create DataFrame
df = pd.DataFrame(song_features)

# Add song titles to the DataFrame
df['song_title'] = song_titles

# %%
df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.814   0.676   11    -4.670     0       0.2310      0.007090
# 1         0.695   0.633    8    -4.946     1       0.0599      0.061200
# 2         0.716   0.531    7    -7.355     1       0.1220      0.070300
# 3         0.908   0.621    1    -6.638     0       0.1020      0.000282
# 4         0.800   0.585   10    -7.343     1       0.0924      0.264000
# 5         0.665   0.535    4    -7.056     0       0.0572      0.078600
# 6         0.711   0.611    1    -5.453     1       0.3300      0.005880
# 7         0.693   0.445    8    -5.892     1       0.2570      0.006250
# 8         0.796   0.766    7    -5.974     1       0.2380      0.074200
# 9         0.638   0.523    1    -6.664     1       0.3570      0.004540
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000013    0.1190    0.312  162.012  audio_features
# ...

# %%
# Function to retrieve top tracks and song features for an artist
def get_top_tracks_and_features(artist_name):
    # Search for the artist
    results = sp.search(q=artist_name, type='artist')
    artist_id = results['artists']['items'][0]['id']

    # Get the artist's top tracks
    tracks = sp.artist_top_tracks(artist_id)
    track_ids = [track['id'] for track in tracks['tracks']]

    # Get audio features for each track
    song_features = []
    song_titles = []
    for track_id in track_ids:
        features = sp.audio_features([track_id])
        song_features.extend(features)

        # Extract song titles
        track_info = sp.track(track_id)
        song_titles.append(track_info['name'])

    return song_features, song_titles

# Get top tracks and features for Kendrick Lamar
kendrick_features, kendrick_titles = get_top_tracks_and_features('Kendrick Lamar')

# Create DataFrame for Kendrick Lamar
kendrick_df = pd.DataFrame(kendrick_features)
kendrick_df['artist'] = 'Kendrick Lamar'
kendrick_df['song_title'] = kendrick_titles

# Get top tracks and features for Lana Del Rey
lana_features, lana_titles = get_top_tracks_and_features('Lana Del Rey')

# Create DataFrame for Lana Del Rey
lana_df = pd.DataFrame(lana_features)
lana_df['artist'] = 'Lana Del Rey'
lana_df['song_title'] = lana_titles

# Concatenate Kendrick Lamar's DataFrame and Lana Del Rey's DataFrame
df = pd.concat([kendrick_df, lana_df], ignore_index=True)

# Print the combined DataFrame
print(df)

# %%
# Function to retrieve top tracks and song features for an artist
def get_top_tracks_and_features(artist_name):
    # Search for the artist
    results = sp.search(q=artist_name, type='artist')
    artist_id = results['artists']['items'][0]['id']

    # Get the artist's top tracks
    tracks = sp.artist_top_tracks(artist_id)
    track_ids = [track['id'] for track in tracks['tracks']]

    # Get audio features for each track
    song_features = []
    song_titles = []
    for track_id in track_ids:
        features = sp.audio_features([track_id])
        song_features.extend(features)

        # Extract song titles
        track_info = sp.track(track_id)
        song_titles.append(track_info['name'])

    return song_features, song_titles

# Get top tracks and features for Kendrick Lamar
kendrick_features, kendrick_titles = get_top_tracks_and_features('Kendrick Lamar')

# Create DataFrame for Kendrick Lamar
kendrick_df = pd.DataFrame(kendrick_features)
kendrick_df['artist'] = 'Kendrick Lamar'
kendrick_df['song_title'] = kendrick_titles

# Get top tracks and features for Lana Del Rey
lana_features, lana_titles = get_top_tracks_and_features('Lana Del Rey')

# Create DataFrame for Lana Del Rey
lana_df = pd.DataFrame(lana_features)
lana_df['artist'] = 'Lana Del Rey'
lana_df['song_title'] = lana_titles

# Get top tracks and features for Sabrina Carpenter
sabrina_features, sabrina_titles = get_top_tracks_and_features('Sabrina Carpenter')

# Create DataFrame for Sabrina Carpenter
sabrina_df = pd.DataFrame(sabrina_features)
sabrina_df['artist'] = 'Sabrina Carpenter'
sabrina_df['song_title'] = sabrina_titles

# Concatenate all DataFrames
df = pd.concat([kendrick_df, lana_df, sabrina_df], ignore_index=True)

# %%
# Function to retrieve top tracks and song features for an artist
def get_top_tracks_and_features(artist_name):
    # Search for the artist
    results = sp.search(q=artist_name, type='artist')
    artist_id = results['artists']['items'][0]['id']

    # Get the artist's top tracks
    tracks = sp.artist_top_tracks(artist_id)
    track_ids = [track['id'] for track in tracks['tracks']]

    # Get audio features for each track
    song_features = []
    song_titles = []
    for track_id in track_ids:
        features = sp.audio_features([track_id])
        song_features.extend(features)

        # Extract song titles
        track_info = sp.track(track_id)
        song_titles.append(track_info['name'])

    return song_features, song_titles

# Get top tracks and features for Troye Sivan
troye_features, troye_titles = get_top_tracks_and_features('Troye Sivan')

# Create DataFrame for Troye Sivan
troye_df = pd.DataFrame(troye_features)
troye_df['artist'] = 'Troye Sivan'
troye_df['song_title'] = troye_titles

# Concatenate all DataFrames
df = pd.concat([df, troye_df], ignore_index=True)

# %%
# Function to retrieve top tracks and song features for an artist
def get_top_tracks_and_features(artist_name):
    # Search for the artist
    results = sp.search(q=artist_name, type='artist')
    artist_id = results['artists']['items'][0]['id']

    # Get the artist's top tracks
    tracks = sp.artist_top_tracks(artist_id)
    track_ids = [track['id'] for track in tracks['tracks']]

    # Get audio features for each track
    song_features = []
    song_titles = []
    for track_id in track_ids:
        features = sp.audio_features([track_id])
        song_features.extend(features)

        # Extract song titles
        track_info = sp.track(track_id)
        song_titles.append(track_info['name'])

    return song_features, song_titles

# Initialize an empty DataFrame
df = pd.DataFrame()

# List of artists
artists = [
    'Dua Lipa', 'Tate McRae', 'Benson Boone', 'bbno$', 'Beyonce', 'Olivia Rodrigo', 'The Kid LAROI', 'Hozier',
    'Miley Cyrus', 'Ariana Grande', 'Zach Bryan', 'Kacey Musgraves', 'Taylor Swift', 'Noah Kahan', 'Post Malone',
    'SZA', 'Luke Combs', 'Tyla', 'Sabrina Carpenter', 'Morgan Wallen', 'Cardi B', 'Lainey Wilson', 'Thomas Rhett',
    'The Weeknd', 'Sam Hunt', 'Tyler Hubbard', 'Jordan Davis', 'Chris Stapleton', 'Josh Ross', 'Bailey Zimmerman',
    'Ice Spice', 'Holly Humberstone', 'Bleachers', 'Maggie Rogers', 'FLETCHER', 'Glass Animals', 'Conan Gray',
    'Chappell Roan', 'Waxahatchee', 'The Japanese House', 'PinkPantheress', 'King Princess', 'MUNA', 'Phoebe Bridgers',
    'Artemas', 'Fred again...', 'Pop Smoke', 'HAIM', 'Charli XCX', 'Christine and the Queens', 'Vampire Weekend',
    'ODESZA', 'FKA twigs', 'Jacob Collier', 'Sturgill Simpson', 'Alex Cameron', 'Caroline Polachek', 'Florence + The Machine',
    'La Roux', 'Rina Sawayama', 'BANKS', 'Twin Shadow', 'Jamie xx', 'The XX', 'Issy Wood', 'Medium Build', 'Mura Masa',
    'Brittany Howard', 'Black Pumas', 'Suki Waterhouse', 'Whitney', 'Big Thief', 'Tove Lo', 'Billie Eilish', 'Skrillex',
    'SG Lewis', 'Romy', 'Sam Hunt', 'Big Kill', 'The 1975', 'Chappell Roan', 'Eric Church', 'Remi Wolf'
]

# Iterate through each artist
for artist in artists:
    # Get top tracks and features for the artist
    artist_features, artist_titles = get_top_tracks_and_features(artist)

    # Create DataFrame for the artist
    artist_df = pd.DataFrame(artist_features)
    artist_df['artist'] = artist
    artist_df['song_title'] = artist_titles

    # Concatenate artist DataFrame with the main DataFrame
    df = pd.concat([df, artist_df], ignore_index=True)

# %%
# Function to retrieve top tracks and song features for an artist
def get_top_tracks_and_features(artist_name):
    # Search for the artist
    results = sp.search(q=artist_name, type='artist')
    artist_id = results['artists']['items'][0]['id']

    # Get the artist's top tracks
    tracks = sp.artist_top_tracks(artist_id)
    track_ids = [track['id'] for track in tracks['tracks']]

    # Get audio features for each track
    song_features = []
    song_titles = []
    for track_id in track_ids:
        features = sp.audio_features([track_id])
        song_features.extend(features)

        # Extract song titles
        track_info = sp.track(track_id)
        song_titles.append(track_info['name'])

    return song_features, song_titles

# Initialize an empty DataFrame
df = pd.DataFrame()

# List of artists
artists = [


]

# Iterate through each artist
for artist in artists:
    # Get top tracks and features for the artist
    artist_features, artist_titles = get_top_tracks_and_features(artist)

    # Create DataFrame for the artist
    artist_df = pd.DataFrame(artist_features)
    artist_df['artist'] = artist
    artist_df['song_title'] = artist_titles

    # Concatenate artist DataFrame with the main DataFrame
    df = pd.concat([df, artist_df], ignore_index=True)
# Out:
#   File "<ipython-input-31-bcc3940d94f7>", line 29
# ...

# %%
df
# Out:
#      danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0           0.812   0.587   5.0    -4.483   0.0       0.0477        0.0349
# 1           0.744   0.789   9.0    -4.876   0.0       0.0590        0.0036
# 2           0.677   0.763   8.0    -4.701   0.0       0.0471        0.0235
# 3           0.671   0.845  11.0    -4.930   0.0       0.0480        0.0207
# 4           0.795   0.800   1.0    -6.320   1.0       0.0309        0.0354
# ..            ...     ...   ...       ...   ...          ...           ...
# 815         0.572   0.790   5.0    -3.866   0.0       0.1320        0.1390
# 816         0.906   0.462   7.0    -9.486   1.0       0.0960        0.1720
# 817         0.822   0.660   1.0    -3.637   1.0       0.0819        0.1110
# 818         0.664   0.477   0.0   -10.530   1.0       0.0551        0.3940
# 819         0.687   0.654   3.0    -6.588   1.0       0.0314        0.0538
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...
